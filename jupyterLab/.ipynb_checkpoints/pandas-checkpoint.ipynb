# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
# %matplotlib inline

# %%
df = pd.read_csv('sample.CSV', sep=',', quotechar='"', decimal=',')

# %%
df.head()
# Out:
#                     TS                                              SC_PD  \
# 0  27.06.2018 10:06:28  STB_MON_UnPluged, IFB_UnPluged, VAU_UnPluged, ...
# 1  27.06.2018 10:06:33  STB_MON_UnPluged, IFB_UnPluged, VAU_UnPluged, ...
# 2  27.06.2018 10:06:38  STB_MON_UnPluged, IFB_UnPluged, VAU_UnPluged, ...
# 3  27.06.2018 10:06:43  STB_MON_UnPluged, IFB_UnPluged, VAU_UnPluged, ...
# 4  27.06.2018 10:06:53  STB_MON_UnPluged, IFB_UnPluged, VAU_UnPluged, ...
#
#     SC_DOORKEY             LMI_TIME TXP1_IDENTMODE TXP1_FAN_MODE  \
# 0  Maintenance  27.06.2018 10:03:26    Independent           Off
# 1  Maintenance  27.06.2018 10:03:30    Independent           Off
# 2  Maintenance  27.06.2018 10:03:35    Independent           Off
# 3  Maintenance  27.06.2018 10:03:40    Independent           Off
# 4  Maintenance  27.06.2018 10:03:50    Independent           Off
#
#    TXP1_TXU_TEMP  TXP1_HPA_TEMP  TXP1_DCDC_5V_VOLTAGE  TXP1_DCDC_5V_CURRENT  \
# ...

# %%
col = df.columns
col
# Out:
# Index(['TS', 'SC_PD', 'SC_DOORKEY', 'LMI_TIME', 'TXP1_IDENTMODE',
#        'TXP1_FAN_MODE', 'TXP1_TXU_TEMP', 'TXP1_HPA_TEMP',
#        'TXP1_DCDC_5V_VOLTAGE', 'TXP1_DCDC_5V_CURRENT',
#        ...
#        'EM_DIGITAL_INPUT8', 'EM_DIGITAL_INPUT9', 'EM_DIGITAL_INPUT10',
#        'EM_DIGITAL_INPUT11', 'EM_DIGITAL_INPUT12', 'EM_DIGITAL_INPUT13',
#        'EM_DIGITAL_INPUT14', 'EM_DIGITAL_INPUT15', 'EM_DIGITAL_INPUT16',
#        'EM_TEMPSENSOR'],
#       dtype='object', length=201)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12522, step=1)

# %%
df.TS.head()
# Out:
# 0    27.06.2018 10:06:28
# 1    27.06.2018 10:06:33
# 2    27.06.2018 10:06:38
# 3    27.06.2018 10:06:43
# 4    27.06.2018 10:06:53
# Name: TS, dtype: object

# %%
desc = df['MON2_TX2_PULSE_DURATION'].describe()
print(desc)
print(desc['max'])
# Out:
# count    12522.000000
# mean         3.604422
# std          0.067272
# min          3.550000
# 25%          3.600000
# 50%          3.600000
# 75%          3.600000
# max          5.780000
# Name: MON2_TX2_PULSE_DURATION, dtype: float64
# 5.78

# %%
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

datetime_format = r'%d.%m.%Y %H:%M:%S'
ts = df['TS'].map(lambda x: datetime.strptime(str(x), datetime_format))

y1 = df['MON2_TX2_PULSE_DURATION']
y2 = df['MON2_TX2_PULSE_RISE_TIME']
y3 = df['MON2_TX2_PEAK_POWER_OUTPUT']

plt1 = ax1.plot(ts, y1)
plt1 = ax1.plot(ts, y2)

plt2 = ax2.plot(ts, y3, color="orange")

ax1.legend()
ax1.grid(True)

ax2.legend()
ax2.grid(True)

#fig.autofmt_xdate()

print('mean=%1.2f, min=%1.2f, max=%1.2f' % (desc['mean'], desc['min'], desc['max']))
plt.show()
# Out:
# mean=3.60, min=3.55, max=5.78

# %%
fig = plt.figure(figsize=(12, 8), dpi=80)
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

datetime_format = r'%d.%m.%Y %H:%M:%S'
ts = df['TS'].map(lambda x: datetime.strptime(str(x), datetime_format))

y1 = df['MON1_TX2_PULSE_DURATION']
y2 = df['MON1_TX2_PULSE_RISE_TIME']
y3 = df['MON1_TX2_PEAK_POWER_OUTPUT']

plt1 = ax1.plot(ts, y1)
plt1 = ax1.plot(ts, y2)

plt2 = ax2.plot(ts, y3, color="orange")

ax1.legend()
ax1.grid(True)

ax2.legend()
ax2.grid(True)

#fig.autofmt_xdate()
plt.show()
